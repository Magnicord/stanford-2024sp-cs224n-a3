# %% [markdown]
# # CS 224N 2024 Spring Assignment 3
#
# ## Motivation
#
# For people in mainland China, applying to use [GCP](https://cloud.google.com/) is a rather tricky thing. Therefore this notebook is created to help run experiments directly on [Google Colab](https://colab.research.google.com/) without having to apply for GCP! It mainly refers to the [UMich EECS498 2020 Fall Colab Tutorial](https://web.eecs.umich.edu/~justincj/teaching/eecs498/FA2020/colab.html). There are some contents suggested to be read in the original tutorial:
#
# - [Upload assignment to Colab](https://web.eecs.umich.edu/~justincj/teaching/eecs498/FA2020/colab.html#upload-assignment-to-colab-top)
# - [Connect to an instance](https://web.eecs.umich.edu/~justincj/teaching/eecs498/FA2020/colab.html#connect-to-an-instance-top)
# - [Run setup code](https://web.eecs.umich.edu/~justincj/teaching/eecs498/FA2020/colab.html#run-setup-code-top)
#
# ## Setup
#
# ### Colab Setup
#
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!) and copy the authorization code into the text box that appears below.

# %%
from google.colab import drive

drive.mount("/content/drive")

# %% [markdown]
# Now recall the path in your Google Drive where you uploaded this notebook, fill it in below. If everything is working correctly, then running the folowing cell should print the filenames from the assignment.

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# `"Course/Stanford/cs224n/2024sp/a3"` is mine. You should change it to your own
GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = "Course/Stanford/cs224n/2024sp/a3"
GOOGLE_DRIVE_PATH = os.path.join(
    "drive", "MyDrive", GOOGLE_DRIVE_PATH_AFTER_MYDRIVE
)
print(os.listdir(GOOGLE_DRIVE_PATH))

# %%
# Change the current working directory to the assignment folder
# Then the script `run.sh` can be executed correctly
os.chdir(GOOGLE_DRIVE_PATH)

# %% [markdown]
# ### Python Environment Setup
#
# Run the following cell to set up your Python environment.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ### TensorBoard Setup

# %% [markdown]
# There is a [tutorial](https://colab.research.google.com/github/pytorch/tutorials/blob/gh-pages/_downloads/tensorboard_with_pytorch.ipynb) on how to use TensorBoard with Pytorch on Colab. However, the tutorial is a bit outdated. The following cell offers a way to use TensorBoard in the notebook directly.

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs --bind_all # similar to `sh run.sh tensorboard`

# %% [markdown]
# ## Run the Experiments
#
# Now you can run the experiments as you would on GCP.

# %%
# !sh run.sh train

# %%
# !sh run.sh test
